# %%
import nltk
import random
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
import json
from nltk.stem import WordNetLemmatizer
from sklearn.preprocessing import OneHotEncoder

# %%
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/shreyaschandrashekar/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
{
  "intents": [
    {
      "tag": "greetings",
      "patterns": [
        "Hi there",
        "How are you",
        "Hello"
      ],
      "responses": [
        "**Hi, I am AYURBOT, a specialized bot for the Ayurvedic specific field and its medications.**\n\nI am designed to provide information and answer questions about Ayurveda, its principles, treatments, and medications. I can also help you find qualified Ayurvedic practitioners and products.\n\nHere are some of the things I can do:\n\n* Answer your questions about Ayurveda\n* Provide information about Ayurvedic treatments and medications\n* Help you find qualified Ayurvedic practitioners\n* Help you find Ayurvedic products\n* Give you personalized Ayurvedic advice\n\nI am still under development, but I am learning more about Ayurveda every day. I am committed to providing accurate and up-to-date information about Ayurveda to help people improve their health and well-being.\n\n**How can I help you today?**"
      ],
      "context": [""]
    },
    {
      "tag": "goodbye",
      "patterns": [
        "Bye",
        "See you later",
        "Goodbye"
      ],
      "responses": [
        "See you later, Bye Bye"
      ],
      "context": [""]
    },
    {
      "tag": "thanks",
      "patterns": [
        "Thanks",
        "Thank you"
      ],
      "responses": [
        "Happy to help you"
      ],
      "context": [""]
    },
    {
      "tag": "cold",
      "patterns": [
        "I have cold",
        "cold",
        "Ayurvedic medication for cold",
        "medication for cold"
      ],
      "responses": [
        "**Herbal Remedies:**\n\n* **Ginger (Zingiber officinale):** Antibacterial, antiviral, and anti-inflammatory. Boil ginger in water and sip as a tea.\n* **Honey:** Antibacterial and soothing. Add honey to warm water or tea.\n* **Turmeric (Curcuma longa):** Anti-inflammatory and antimicrobial. Grind turmeric into a paste and apply to the chest or take as a capsule.\n* **Tulsi (Ocimum sanctum):** Antibacterial, antiviral, and immune-boosting. Boil tulsi leaves in water and drink as a tea.\n* **Guduchi (Tinospora cordifolia):** Boosts immunity and reduces inflammation. Take as a capsule or tea.\n\n**Rasayana Remedies (Rejuvenating Tonics):**\n\n* **Chyavanprash:** A polyherbal jam containing amla (Indian gooseberry), honey, and other herbs. Boosts immunity and provides antioxidants.\n* **Ashwagandha (Withania somnifera):** Adaptogenic herb that reduces stress and enhances immune function. Take as a capsule or powder.\n* **Triphala:** A combination of three fruits (amla, bibhitaki, and haritaki). Cleanses the body and supports digestion, which can improve immunity.\n\n**Nasal Remedies:**\n\n* **Nasya Oil:** Medicated oil that is applied to the nasal passages to clear congestion and reduce inflammation.\n* **Steam Inhalation:** Steam helps thin mucus and soothe respiratory passages. Add a few drops of eucalyptus or peppermint essential oil to boiling water and inhale the steam.\n\n**Other Remedies:**\n\n* **Ghee:** Clarified butter that has anti-inflammatory and antimicrobial properties. Ghee can be used to massage the chest or taken internally.\n* **Nasal Irrigation:** Using a neti pot or a saline nasal spray to irrigate the nasal passages can help remove mucus and reduce inflammation.\n* **Rest:** Getting plenty of rest is essential for recovery.\n\n**Note:** It is important to consult with an Ayurvedic practitioner before taking any medications, as some can have contraindications or may not be suitable for everyone."
      ],
      "context": [""]
    },
    {
      "tag": "cough",
      "patterns": [
        "I have cough",
        "cough",
        "Ayurvedic medication for cough"
      ],
      "responses": [
        "**Herbal Remedies:**\n\n* **Ginger (Zingiber officinale):** Anti-inflammatory, antibacterial, and expectorant. Boil ginger in water and sip as a tea.\n* **Honey:** Soothing and antibacterial. Add honey to warm water or tea.\n* **Turmeric (Curcuma longa):** Anti-inflammatory and antimicrobial. Grind turmeric into a paste and apply to the chest or take as a capsule.\n* **Tulsi (Ocimum sanctum):** Antibacterial, antiviral, and expectorant. Boil tulsi leaves in water and drink as a tea.\n* **Marshmallow root (Althaea officinalis):** Soothes and protects the respiratory tract. Take as a tea or capsule.\n\n**Rasayana Remedies (Rejuvenating Tonics):**\n\n* **Chyavanprash:** A polyherbal jam containing amla (Indian gooseberry), honey, and other herbs. Boosts immunity and provides antioxidants.\n* **Ashwagandha (Withania somnifera):** Adaptogenic herb that reduces stress and enhances immune function. Take as a capsule or powder.\n* **Triphala:** A combination of three fruits (amla, bibhitaki, and haritaki). Cleanses the body and supports digestion, which can improve immunity.\n\n**Other Remedies:**\n\n* **Steam Inhalation:** Steam helps thin mucus and soothe respiratory passages. Add a few drops of eucalyptus or peppermint essential oil to boiling water and inhale the steam.\n* **Ghee:** Clarified butter that has anti-inflammatory and expectorant properties. Ghee can be used to massage the chest or taken internally.\n* **Nasal Irrigation:** Using a neti pot or a saline nasal spray to irrigate the nasal passages can help remove mucus and reduce inflammation.\n* **Rest:** Getting plenty of rest is essential for recovery.\n\n**Note:** It is important to consult with an Ayurvedic practitioner before taking any medications, as some can have contraindications or may not be suitable for everyone."
      ],
      "context": [""]
    },
    {
      "tag": "wet cough",
      "patterns": [
        "I have wet cough",
        "Ayurvedic medication for wet cough",
        "wet cough",
        "Ayurvedic medication for dry cough",
        "dry cough",
        "I have dry cough"
      ],
      "responses": [
        "**Ayurvedic Medication for Dry Cough**\n\n* **Honey:** Soothes and lubricates the throat. Take a teaspoon of honey as needed.\n* **Ginger (Zingiber officinale):** Anti-inflammatory and expectorant. Boil ginger in water and sip as a tea.\n* **Turmeric (Curcuma longa):** Anti-inflammatory and antimicrobial. Grind turmeric into a paste and apply to the chest.\n* **Marshmallow root (Althaea officinalis):** Soothes and protects the respiratory tract. Take as a tea or capsule.\n* **Licorice root (Glycyrrhiza glabra):** Soothes and reduces inflammation. Take as a tea or capsule.\n\n**Ayurvedic Medication for Wet Cough**\n\n* **Tulsi (Ocimum sanctum):** Antibacterial, antiviral, and expectorant. Boil tulsi leaves in water and drink as a tea.\n* **Guduchi (Tinospora cordifolia):** Boosts immunity and reduces inflammation. Take as a capsule or tea.\n* **Vasaka (Adhatoda vasica):** Expectorant and bronchodilator. Take as a tea or capsule.\n* **Eucalyptus oil (Eucalyptus globulus):** Antibacterial and expectorant. Add a few drops to a diffuser or steam inhalation.\n* **Steam Inhalation:** Steam helps thin mucus and soothe respiratory passages. Add a few drops of eucalyptus or peppermint essential oil to boiling water and inhale the steam.\n\n**Other Remedies for Both Dry and Wet Cough**\n\n* **Ghee:** Clarified butter that has anti-inflammatory and expectorant properties. Ghee can be used to massage the chest or taken internally.\n* **Nasal Irrigation:** Using a neti pot or a saline nasal spray to irrigate the nasal passages can help remove mucus and reduce inflammation.\n* **Rest:** Getting plenty of rest is essential for recovery.\n\n**Note:** It is important to consult with an Ayurvedic practitioner before taking any medications, as some can have contraindications or may not be suitable for everyone."
      ],
      "context": [""]
    },
    {
      "tag": "headache",
      "patterns": [
        "I have headache",
        "headache",
        "Ayurvedic medication for headache"
      ],
      "responses": [
        "**Ayurvedic Medication for Headache**\n\n**Herbal Remedies:**\n\n* **Ginger (Zingiber officinale):** Anti-inflammatory and pain-relieving. Boil ginger in water and sip as a tea.\n* **Turmeric (Curcuma longa):** Anti-inflammatory and antioxidant. Grind turmeric into a paste and apply to the forehead or take as a capsule.\n* **Holy basil (Ocimum sanctum):** Relieves stress and anxiety, which can trigger headaches. Boil holy basil leaves in water and drink as a tea.\n* **Brahmi (Bacopa monnieri):** Calms the mind and reduces stress. Take as a capsule or tea.\n* **Ashwagandha (Withania somnifera):** Adaptogenic herb that reduces stress and anxiety. Take as a capsule or powder.\n\n**Other Remedies:**\n\n* **Nasya Oil:** Medicated oil that is applied to the nasal passages to relieve congestion and reduce headaches.\n* **Head Massage:** Massaging the scalp and forehead with warm oil can help relieve tension and headaches.\n* **Steam Inhalation:** Steam helps to thin mucus and open up the sinuses, which can reduce headaches. Add a few drops of eucalyptus or peppermint essential oil to boiling water and inhale the steam.\n* **Rest:** Getting plenty of rest is important for recovery from headaches.\n\n**Note:** It is important to consult with an Ayurvedic practitioner before taking any medications, as some can have contraindications or may not be suitable for everyone."
      ],
      "context": [""]
    },
    {
      "tag": "fever",
      "patterns": [
        "I have headache",
        "headache",
        "Ayurvedic medication for headache"
      ],
      "responses": [
        "**Ayurvedic Medication for Fever**\n\n**Herbal Remedies:**\n\n* **Guduchi (Tinospora cordifolia):** Boosts immunity and reduces inflammation. Take as a capsule or tea.\n* **Neem (Azadirachta indica):** Antibacterial, antiviral, and anti-inflammatory. Boil neem leaves in water and drink as a tea.\n* **Turmeric (Curcuma longa):** Anti-inflammatory and antioxidant. Grind turmeric into a paste and apply to the forehead or take as a capsule.\n* **Ginger (Zingiber officinale):** Anti-inflammatory and diaphoretic (promotes sweating). Boil ginger in water and sip as a tea.\n* **Holy basil (Ocimum sanctum):** Antibacterial, antiviral, and anti-inflammatory. Boil holy basil leaves in water and drink as a tea.\n\n**Other Remedies:**\n\n* **Nasya Oil:** Medicated oil that is applied to the nasal passages to reduce inflammation and promote sweating.\n* **Steam Inhalation:** Steam helps to thin mucus and open up the sinuses, which can reduce fever. Add a few drops of eucalyptus or peppermint essential oil to boiling water and inhale the steam.\n* **Lukewarm Bath:** Taking a lukewarm bath can help to reduce body temperature.\n* **Rest:** Getting plenty of rest is important for recovery from fever.\n\n**Note:** It is important to consult with an Ayurvedic practitioner before taking any medications, as some can have contraindications or may not be suitable for everyone."
      ],
      "context": [""]
    },
    {
      "tag": "body pain",
      "patterns": [
        "I have bodypain",
        "bodypain",
        "Ayurvedic medication for bodypain"
      ],
      "responses": [
        "**Ayurvedic Medication for Body Pain**\n\n**Herbal Remedies:**\n\n* **Ashwagandha (Withania somnifera):** Reduces inflammation and pain. Take as a capsule or powder.\n* **Turmeric (Curcuma longa):** Anti-inflammatory and antioxidant. Grind turmeric into a paste and apply to the affected area or take as a capsule.\n* **Ginger (Zingiber officinale):** Anti-inflammatory and pain-relieving. Boil ginger in water and sip as a tea.\n* **Boswellia (Boswellia serrata):** Anti-inflammatory and pain-relieving. Take as a capsule or tea.\n* **Neem (Azadirachta indica):** Anti-inflammatory and pain-relieving. Boil neem leaves in water and use the decoction to bathe or soak the affected area.\n\n**Other Remedies:**\n\n* **Abhyanga Massage:** Ayurvedic massage with warm oil helps to reduce inflammation and pain.\n* **Shirodhara:** A type of Ayurvedic therapy where warm oil is poured over the forehead. This helps to calm the mind and reduce stress, which can contribute to body pain.\n* **Heat Therapy:** Applying heat to the affected area can help to reduce pain and inflammation.\n* **Rest:** Getting plenty of rest is important for recovery from body pain.\n\n**Note:** It is important to consult with an Ayurvedic practitioner before taking any medications or undergoing any therapies, as some can have contraindications or may not be suitable for everyone."
      ],
      "context": [""]
    },
    {
      "tag": "running nose",
      "patterns": [
        "I have running nose",
        "running nose",
        "Ayurvedic medication for running nose"
      ],
      "responses": [
        "**Ayurvedic Medication for Running Nose**\n\n**Herbal Remedies:**\n\n* **Tulsi (Ocimum sanctum):** Antibacterial, antiviral, and expectorant. Boil tulsi leaves in water and drink as a tea.\n* **Ginger (Zingiber officinale):** Anti-inflammatory and expectorant. Boil ginger in water and sip as a tea.\n* **Turmeric (Curcuma longa):** Anti-inflammatory and antioxidant. Grind turmeric into a paste and apply to the nostrils or take as a capsule.\n* **Pippali (Piper longum):** Expectorant and decongestant. Take as a capsule or add to hot water and inhale the steam.\n* **Honey:** Soothes and lubricates the nasal passages. Take a teaspoon of honey as needed.\n\n**Other Remedies:**\n\n* **Nasya Oil:** Medicated oil that is applied to the nasal passages to reduce congestion and inflammation.\n* **Steam Inhalation:** Steam helps to thin mucus and open up the sinuses. Add a few drops of eucalyptus or peppermint essential oil to boiling water and inhale the steam.\n* **Nasal Irrigation:** Using a neti pot or a saline nasal spray to irrigate the nasal passages can help to remove mucus and reduce inflammation.\n* **Rest:** Getting plenty of rest is important for recovery from a running nose.\n\n**Note:** It is important to consult with an Ayurvedic practitioner before taking any medications or undergoing any therapies, as some can have contraindications or may not be suitable for everyone."
      ],
      "context": [""]
    },
    {
      "tag": "sour throat",
      "patterns": [
        "I have sour throat",
        "Ayurvedic medication for sour throat",
        "sour thorat"
      ],
      "responses": [
        "**Ayurvedic Medication for Sore Throat**\n\n**Herbal Remedies:**\n\n* **Honey:** Soothes and lubricates the throat. Take a teaspoon of honey as needed.\n* **Ginger (Zingiber officinale):** Anti-inflammatory and antibacterial. Boil ginger in water and sip as a tea.\n* **Turmeric (Curcuma longa):** Anti-inflammatory and antioxidant. Grind turmeric into a paste and apply to the throat or take as a capsule.\n* **Holy basil (Ocimum sanctum):** Antibacterial, antiviral, and anti-inflammatory. Boil holy basil leaves in water and drink as a tea.\n* **Licorice root (Glycyrrhiza glabra):** Soothes and reduces inflammation. Take as a tea or capsule.\n\n**Other Remedies:**\n\n* **Gargling with Salt Water:** Gargling with warm salt water can help to reduce inflammation and pain.\n* **Steam Inhalation:** Steam helps to thin mucus and soothe the throat. Add a few drops of eucalyptus or peppermint essential oil to boiling water and inhale the steam.\n* **Throat Lozenges:** Ayurvedic throat lozenges containing herbs such as honey, ginger, and turmeric can help to soothe and relieve sore throats.\n* **Rest:** Getting plenty of rest is important for recovery from a sore throat.\n\n**Note:** It is important to consult with an Ayurvedic practitioner before taking any medications or undergoing any therapies, as some can have contraindications or may not be suitable for everyone."
      ],
      "context": [""]
    },
    {
      "tag": "red eyes",
      "patterns": [
        "I have red eyes",
        "red eyes",
        "Ayurvedic medication for red eyes"
      ],
      "responses": [
        "**Ayurvedic Medication for Red Eyes**\n\n**Herbal Remedies:**\n\n* **Triphala:** A combination of three fruits (amla, bibhitaki, and haritaki) that is cooling and soothing to the eyes. Take as a capsule or tea.\n* **Aloe vera:** Anti-inflammatory and cooling. Apply aloe vera gel to the eyes or take as a juice.\n* **Rose water:** Cooling and refreshing. Splash rose water on the eyes or use as an eye wash.\n* **Cucumber:** Cooling and hydrating. Place slices of cucumber over the eyes.\n* **Indian gooseberry (amla):** Rich in vitamin C and antioxidants, which are beneficial for eye health. Take as a capsule or eat fresh.\n\n**Other Remedies:**\n\n* **Eye Drops:** Ayurvedic eye drops containing herbs such as triphala, aloe vera, and rose water can help to soothe and reduce redness.\n* **Eye Massage:** Gently massaging the area around the eyes can help to improve circulation and reduce inflammation.\n* **Rest:** Getting plenty of rest is important for eye health.\n* **Sunglasses:** Wearing sunglasses when outdoors can help to protect the eyes from the sun's harmful UV rays.\n\n**Note:** It is important to consult with an Ayurvedic practitioner before taking any medications or undergoing any therapies, as some can have contraindications or may not be suitable for everyone."
      ],
      "context": [""]
    },
    {
      "tag": "joints pain",
      "patterns": [
        "I have joints pain",
        "joints pain",
        "Ayurvedic medication for joints pain"
      ],
      "responses": [
        "**Ayurvedic Medication for Joint Pain**\n\n**Herbal Remedies:**\n\n* **Ashwagandha (Withania somnifera):** Reduces inflammation and pain. Take as a capsule or powder.\n* **Turmeric (Curcuma longa):** Anti-inflammatory and antioxidant. Grind turmeric into a paste and apply to the affected joints or take as a capsule.\n* **Boswellia (Boswellia serrata):** Anti-inflammatory and pain-relieving. Take as a capsule or tea.\n* **Ginger (Zingiber officinale):** Anti-inflammatory and pain-relieving. Boil ginger in water and sip as a tea.\n* **Neem (Azadirachta indica):** Anti-inflammatory and pain-relieving. Boil neem leaves in water and use the decoction to bathe or soak the affected joints.\n\n**Other Remedies:**\n\n* **Abhyanga Massage:** Ayurvedic massage with warm oil helps to reduce inflammation and pain.\n* **Shirodhara:** A type of Ayurvedic therapy where warm oil is poured over the forehead. This helps to calm the mind and reduce stress, which can contribute to joint pain.\n* **Heat Therapy:** Applying heat to the affected joints can help to reduce pain and inflammation.\n* **Rest:** Getting plenty of rest is important for recovery from joint pain.\n\n**Note:** It is important to consult with an Ayurvedic practitioner before taking any medications or undergoing any therapies, as some can have contraindications or may not be suitable for everyone."
      ],
      "context": [""]
    },
    {
      "tag": "arthritis",
      "patterns": [
        "I have arthritis",
        "arthritis",
        "Ayurvedic medication for arthritis"
      ],
      "responses": [
        "**Ayurvedic Medication for Arthritis**\n\n**Herbal Remedies:**\n\n* **Ashwagandha (Withania somnifera):** Reduces inflammation and pain. Take as a capsule or powder.\n* **Turmeric (Curcuma longa):** Anti-inflammatory and antioxidant. Grind turmeric into a paste and apply to the affected joints or take as a capsule.\n* **Boswellia (Boswellia serrata):** Anti-inflammatory and pain-relieving. Take as a capsule or tea.\n* **Ginger (Zingiber officinale):** Anti-inflammatory and pain-relieving. Boil ginger in water and sip as a tea.\n* **Neem (Azadirachta indica):** Anti-inflammatory and pain-relieving. Boil neem leaves in water and use the decoction to bathe or soak the affected joints.\n\n**Other Remedies:**\n\n* **Abhyanga Massage:** Ayurvedic massage with warm oil helps to reduce inflammation and pain.\n* **Shirodhara:** A type of Ayurvedic therapy where warm oil is poured over the forehead. This helps to calm the mind and reduce stress, which can contribute to arthritis.\n* **Heat Therapy:** Applying heat to the affected joints can help to reduce pain and inflammation.\n* **Rest:** Getting plenty of rest is important for recovery from arthritis.\n\n**Note:** It is important to consult with an Ayurvedic practitioner before taking any medications or undergoing any therapies, as some can have contraindications or may not be suitable for everyone."
      ],
      "context": [""]
    },
    {
      "tag": "cancer",
      "patterns": [
        "I have cancer",
        "cancer",
        "Ayurvedic medication for cancer"
      ],
      "responses": [
        "**Basic Ayurvedic Medication for Cancer**\n\n**Herbal Remedies:**\n\n* **Ashwagandha (Withania somnifera):** Boosts immunity and reduces inflammation. Take as a capsule or powder.\n* **Turmeric (Curcuma longa):** Anti-inflammatory and antioxidant. Grind turmeric into a paste and apply to the affected area or take as a capsule.\n* **Guduchi (Tinospora cordifolia):** Boosts immunity and reduces inflammation. Take as a capsule or tea.\n* **Neem (Azadirachta indica):** Anti-cancer and anti-inflammatory. Boil neem leaves in water and drink as a tea.\n* **Ginger (Zingiber officinale):** Anti-inflammatory and pain-relieving. Boil ginger in water and sip as a tea.\n\n**Other Remedies:**\n\n* **Panchakarma:** A detoxification therapy that helps to remove toxins from the body.\n* **Yoga and Meditation:** These practices help to reduce stress and improve overall well-being.\n* **Dietary Modifications:** Following an Ayurvedic diet that is tailored to the individual's needs can help to support the body's natural healing abilities.\n\n**Note:** It is important to consult with an Ayurvedic practitioner before taking any medications or undergoing any therapies, as some can have contraindications or may not be suitable for everyone. Ayurvedic treatment for cancer is typically used in conjunction with conventional medical treatment."
      ],
      "context": [""]
    },
    {
      "tag": "drugs and its uses",
      "patterns": [
        "Describe these drugs and it's uses and all it's sub varients:(A) Asava AristaB) Arka Kalpana(C) Avaleha, Khand, Pak Kalpana(D) Kvatha Churna/Kashayam(E) Guggulu(F) Ghrita(G) Chuma - Multi-ingredient(H) Churna - Single Ingredient(I) Taila(J) Lavana & Kshara(K) Lepa for local application(L) Vati& Gutika(M) Varti, Netrabindu, Anjana(N) Sattva(O) Parpati(P) Pishti Kalpana(Q) Bhasma(R) Mandura(S) Rasayoga(T) Lauha"
      ],
      "responses": [
        "**A) Asava Arista**\n\n* **Description:** Fermented decoctions of herbs, fruits, and spices in a jaggery or honey base.\n* **Uses:** To improve digestion, boost immunity, and treat various ailments.\n* **Sub-variants:**\n    * Asava: Fermented decoctions with a higher alcohol content.\n    * Arista: Fermented decoctions with a lower alcohol content.\n\n**B) Arka Kalpana**\n\n* **Description:** Distilled extracts of herbs or other plant materials.\n* **Uses:** To treat respiratory ailments, digestive disorders, and skin conditions.\n\n**C) Avaleha, Khand, Pak Kalpana**\n\n* **Description:** Thick, semi-solid preparations made from herbs, fruits, and spices cooked in a sugar or honey base.\n* **Uses:** To treat respiratory ailments, digestive disorders, and general weakness.\n* **Sub-variants:**\n    * Avaleha: Thick, sticky preparations.\n    * Khand: Hardened, sugar-based preparations.\n    * Pak: Cooked preparations with a thick consistency.\n\n**D) Kvatha Churna/Kashayam**\n\n* **Description:** Decoctions made by boiling herbs in water.\n* **Uses:** To treat various ailments, including digestive disorders, respiratory problems, and fever.\n\n**E) Guggulu**\n\n* **Description:** Resin from the guggul tree.\n* **Uses:** To treat arthritis, obesity, and cholesterol disorders.\n\n**F) Ghrita**\n\n* **Description:** Clarified butter infused with herbs or other ingredients.\n* **Uses:** To improve digestion, boost immunity, and treat various ailments.\n\n**G) Churna - Multi-ingredient**\n\n* **Description:** Powdered mixtures of multiple herbs.\n* **Uses:** To treat a wide range of ailments, depending on the specific herbs used.\n\n**H) Churna - Single Ingredient**\n\n* **Description:** Powdered form of a single herb.\n* **Uses:** To treat specific ailments or support overall health.\n\n**I) Taila**\n\n* **Description:** Medicated oils infused with herbs or other ingredients.\n* **Uses:** For external application to treat skin conditions, muscle pain, and other ailments.\n\n**J) Lavana & Kshara**\n\n* **Description:** Salts and alkaline substances used in Ayurvedic medicine.\n* **Uses:** To treat digestive disorders, skin conditions, and other ailments.\n\n**K) Lepa for local application**\n\n* **Description:** Pastes made from herbs, minerals, or other ingredients for external application.\n* **Uses:** To treat skin conditions, wounds, and other local ailments.\n\n**L) Vati& Gutika**\n\n* **Description:** Tablets or pills made from powdered herbs or other ingredients.\n* **Uses:** To treat a wide range of ailments, depending on the specific ingredients used.\n\n**M) Varti, Netrabindu, Anjana**\n\n* **Description:** Eye drops, ointments, or pastes used for eye care.\n* **Uses:** To treat eye infections, improve vision, and soothe irritated eyes.\n\n**N) Sattva**\n\n* **Description:** The essence or extract of a herb or other plant material.\n* **Uses:** To treat various ailments, including digestive disorders and respiratory problems.\n\n**O) Parpati**\n\n* **Description:** Thin sheets of metal or minerals used in Ayurvedic medicine.\n* **Uses:** To treat various ailments, including respiratory problems and skin conditions.\n\n**P) Pishti Kalpana**\n\n* **Description:** Powders made from calcined metals or minerals.\n* **Uses:** To treat various ailments, including respiratory problems and digestive disorders.\n\n**Q) Bhasma**\n\n* **Description:** Ash prepared by incinerating metals or minerals.\n* **Uses:** To treat various ailments, including respiratory problems and skin conditions.\n\n**R) Mandura**\n\n* **Description:** Iron oxide used in Ayurvedic medicine.\n* **Uses:** To treat anemia, weakness, and other blood-related disorders.\n\n**S) Rasayoga**\n\n* **Description:** Combinations of mercury, sulfur, and other metals or minerals.\n* **Uses:** To treat various ailments, including respiratory problems, digestive disorders, and skin conditions.\n\n**T) Lauha**\n\n* **Description:** Iron used in Ayurvedic medicine.\n* **Uses:** To treat anemia, weakness, and other blood-related disorders."
      ],
      "context": [""]
    },
    {
      "tag": "diabetes",
      "patterns": [
        "I have diabetes",
        "diabetes",
        "Ayurvedic medication for diabetes"
      ],
      "responses": [
        "**Ayurvedic Medication for Diabetes**\n\n**Herbal Remedies:**\n\n* **Guduchi (Tinospora cordifolia):** Boosts immunity and reduces inflammation. Take as a capsule or tea.\n* **Neem (Azadirachta indica):** Anti-diabetic and anti-inflammatory. Boil neem leaves in water and drink as a tea.\n* **Bitter gourd (Momordica charantia):** Lowers blood sugar levels. Take as a juice or capsule.\n* **Turmeric (Curcuma longa):** Anti-inflammatory and antioxidant. Grind turmeric into a paste and apply to the skin or take as a capsule.\n* **Fenugreek (Trigonella foenum-graecum):** Lowers blood sugar levels and improves insulin sensitivity. Take as a seed powder or capsule.\n\n**Other Remedies:**\n\n* **Panchakarma:** A detoxification therapy that helps to remove toxins from the body and improve overall health.\n* **Yoga and Meditation:** These practices help to reduce stress and improve blood sugar control.\n* **Dietary Modifications:** Following an Ayurvedic diet that is tailored to the individual's needs can help to manage blood sugar levels.\n\n**Note:** It is important to consult with an Ayurvedic practitioner before taking any medications or undergoing any therapies, as some can have contraindications or may not be suitable for everyone. Ayurvedic treatment for diabetes is typically used in conjunction with conventional medical treatment."
      ],
      "context": [""]
    },
    {
      "tag": "heart disease",
      "patterns": [
        "I have heart disease",
        "heart disease",
        "Ayurvedic medication for heart disease"
      ],
      "responses": [
        "**Ayurvedic Medication for Heart Disease**\n\n**Herbal Remedies:**\n\n* **Arjuna (Terminalia arjuna):** Supports heart health and reduces inflammation. Take as a capsule or tea.\n* **Ashwagandha (Withania somnifera):** Reduces stress and anxiety, which can contribute to heart disease. Take as a capsule or powder.\n* **Turmeric (Curcuma longa):** Anti-inflammatory and antioxidant. Grind turmeric into a paste and apply to the skin or take as a capsule.\n* **Garlic (Allium sativum):** Lowers cholesterol and blood pressure. Take as a clove or capsule.\n* **Ginger (Zingiber officinale):** Improves circulation and reduces inflammation. Boil ginger in water and sip as a tea.\n\n**Other Remedies:**\n\n* **Panchakarma:** A detoxification therapy that helps to remove toxins from the body and improve overall health.\n* **Yoga and Meditation:** These practices help to reduce stress and improve heart health.\n* **Dietary Modifications:** Following an Ayurvedic diet that is tailored to the individual's needs can help to manage heart disease risk factors.\n\n**Note:** It is important to consult with an Ayurvedic practitioner before taking any medications or undergoing any therapies, as some can have contraindications or may not be suitable for everyone. Ayurvedic treatment for heart disease is typically used in conjunction with conventional medical treatment."
      ],
      "context": [""]
    },
    {
      "tag": "pregnancy",
      "patterns": [
        "Pregnancy",
        "Ayurvedic medication for pregnancy"
      ],
      "responses": [
        "**Ayurvedic Medication for Pregnancy**\n\n**Herbal Remedies:**\n\n* **Shatavari (Asparagus racemosus):** Supports female reproductive health and nourishes the body. Take as a capsule or powder.\n* **Ashwagandha (Withania somnifera):** Reduces stress and anxiety, which can be common during pregnancy. Take as a capsule or powder.\n* **Guduchi (Tinospora cordifolia):** Boosts immunity and helps to prevent infections. Take as a capsule or tea.\n* **Ginger (Zingiber officinale):** Relieves nausea and vomiting. Boil ginger in water and sip as a tea.\n* **Triphala:** A combination of three fruits (amla, bibhitaki, and haritaki) that supports digestion and overall health. Take as a capsule or tea.\n\n**Other Remedies:**\n\n* **Abhyanga Massage:** A gentle massage with warm oil that helps to reduce stress and improve circulation.\n* **Yoga and Meditation:** These practices help to reduce stress and promote relaxation.\n* **Dietary Modifications:** Following an Ayurvedic diet that is tailored to the individual's needs can help to support a healthy pregnancy.\n\n**Note:** It is important to consult with an Ayurvedic practitioner before taking any medications or undergoing any therapies, as some can have contraindications or may not be suitable for everyone. Ayurvedic treatment for pregnancy is typically used in conjunction with conventional prenatal care."
      ],
      "context": [""]
    },
    {
      "tag": "stomachache",
      "patterns": [
        "I have stomach pain",
        "Stomach pain",
        "stomachache",
        "Ayurvedic medication for stomachache",
        "Ayurvedic medication for stomach pain"
      ],
      "responses": [
        "**Ayurvedic Medication for Stomach Ache**\n\n**Herbal Remedies:**\n\n* **Ginger (Zingiber officinale):** Anti-inflammatory and pain-relieving. Boil ginger in water and sip as a tea.\n* **Fennel (Foeniculum vulgare):** Soothes the digestive tract and reduces gas. Take as a tea or chew on the seeds.\n* **Cumin (Cuminum cyminum):** Improves digestion and relieves gas. Take as a tea or add to food.\n* **Turmeric (Curcuma longa):** Anti-inflammatory and pain-relieving. Grind turmeric into a paste and apply to the abdomen or take as a capsule.\n* **Peppermint (Mentha piperita):** Soothes the digestive tract and reduces gas. Take as a tea or apply peppermint oil to the abdomen.\n\n**Other Remedies:**\n\n* **Abhyanga Massage:** A gentle massage with warm oil that helps to reduce stress and improve digestion.\n* **Yoga and Meditation:** These practices help to reduce stress and promote relaxation, which can improve digestion.\n* **Dietary Modifications:** Following an Ayurvedic diet that is tailored to the individual's needs can help to improve digestion and prevent stomach aches.\n\n**Note:** It is important to consult with an Ayurvedic practitioner before taking any medications or undergoing any therapies, as some can have contraindications or may not be suitable for everyone."
      ],
      "context": [""]
    },
    {
      "tag": "ayurvedic medication",
      "patterns": [
        "Ayurvedic medication",
        "ayurvedic medicines"
      ],
      "responses": [
        "**Ayurvedic Medications**\n\nAyurvedic medicine is a traditional system of medicine that originated in India thousands of years ago. It is based on the belief that health and well-being are achieved through a balance of the three doshas: vata, pitta, and kapha. Ayurvedic medications are typically made from natural ingredients, such as herbs, minerals, and metals.\n\n**Types of Ayurvedic Medications**\n\nThere are many different types of Ayurvedic medications, each with its own unique properties and uses. Some of the most common types include:\n\n* **Herbal Remedies:** These are made from plants and their extracts. They can be taken in a variety of forms, such as teas, capsules, and powders.\n* **Mineral Remedies:** These are made from minerals and metals. They are often used to treat conditions such as anemia and osteoporosis.\n* **Metal Remedies:** These are made from metals such as gold, silver, and copper. They are often used to treat conditions such as arthritis and skin diseases.\n* **Ghee:** This is a clarified butter that is used in many Ayurvedic preparations. It is believed to have healing properties and is often used to improve digestion and boost immunity.\n* **Honey:** This is a natural sweetener that is used in many Ayurvedic preparations. It is believed to have antibacterial and antioxidant properties.\n\n**Uses of Ayurvedic Medications**\n\nAyurvedic medications are used to treat a wide range of conditions, including:\n\n* Digestive disorders\n* Respiratory disorders\n* Skin disorders\n* Musculoskeletal disorders\n* Neurological disorders\n* Mental health disorders\n\n**Benefits of Ayurvedic Medications**\n\nAyurvedic medications offer a number of benefits, including:\n\n* They are made from natural ingredients, so they are generally safe and well-tolerated.\n* They are effective in treating a wide range of conditions.\n* They can help to improve overall health and well-being.\n\n**Cautions**\n\nIt is important to note that Ayurvedic medications can interact with other medications, so it is important to talk to your doctor before taking any Ayurvedic supplements. Additionally, some Ayurvedic medications may not be suitable for people with certain health conditions."
      ],
      "context": [""]
    },
    {
      "tag": "advancement of ayurveda",
      "patterns": [
        "advancements of ayurveda",
        "ayurveda"
      ],
      "responses": [
        "**Advancements in Ayurveda**\n\nAyurveda, the traditional Indian system of medicine, has been practiced for thousands of years. In recent decades, there has been a growing interest in Ayurveda worldwide, and a number of advancements have been made in the field.\n\n**Clinical Research**\n\nOne of the most significant advancements in Ayurveda has been the increasing amount of clinical research that is being conducted. This research is helping to validate the effectiveness of Ayurvedic treatments for a variety of conditions. For example, a number of studies have shown that Ayurvedic herbs and minerals can be effective in treating conditions such as arthritis, asthma, and diabetes.\n\n**Integration with Modern Medicine**\n\nAnother advancement in Ayurveda has been the increasing integration of Ayurvedic principles and practices with modern medicine. This is leading to the development of new and innovative treatments for a variety of diseases. For example, some hospitals and clinics are now offering Ayurvedic treatments alongside conventional medical treatments.\n\n**Standardization of Ayurvedic Products**\n\nIn the past, one of the challenges of Ayurveda was the lack of standardization of Ayurvedic products. This has led to concerns about the quality and safety of some Ayurvedic products. However, in recent years, there has been a growing effort to standardize Ayurvedic products. This is helping to ensure that Ayurvedic products are safe and effective.\n\n**Education and Training**\n\nThere has also been a growing emphasis on education and training in Ayurveda. This is helping to ensure that Ayurvedic practitioners are well-qualified and knowledgeable. In addition, a number of universities and colleges now offer degree programs in Ayurveda.\n\n**Government Support**\n\nIn recent years, there has been increasing government support for Ayurveda. This support has helped to fund research and education in Ayurveda. It has also helped to promote the use of Ayurveda in public health programs.\n\n**Future of Ayurveda**\n\nThe future of Ayurveda is bright. As clinical research continues to validate the effectiveness of Ayurvedic treatments, Ayurveda is likely to become more widely accepted and integrated into mainstream healthcare. In addition, the growing emphasis on education and training will help to ensure that Ayurvedic practitioners are well-qualified and knowledgeable."
      ],
      "context": [""]
    },
    {
      "tag": "side effects of ayurveda",
      "patterns": [
        "side effects of ayurveda",
        "bad effects of ayurveda",
        "disadvantages of ayurveda"
      ],
      "responses": [
        "**Side Effects of Ayurvedic Medications**\n\n**Most Ayurvedic medications are considered safe when taken as directed. However, some Ayurvedic medications can cause side effects, especially if they are taken in high doses or for long periods of time.**\n\n**Some of the most common side effects of Ayurvedic medications include:**\n\n* **Gastrointestinal upset:** Ayurvedic medications can cause nausea, vomiting, diarrhea, and abdominal pain.\n* **Skin reactions:** Ayurvedic medications can cause skin rashes, itching, and irritation.\n* **Allergic reactions:** Some people may be allergic to certain Ayurvedic medications.\n* **Interactions with other medications:** Ayurvedic medications can interact with other medications, including prescription drugs, over-the-counter medications, and herbal supplements.\n* **Heavy metal toxicity:** Some Ayurvedic medications contain heavy metals, such as lead and mercury. These metals can be toxic if they are taken in high doses or for long periods of time.\n\n**It is important to talk to your doctor before taking any Ayurvedic medications, especially if you are pregnant, breastfeeding, or have any health conditions.** Your doctor can help you to choose the right Ayurvedic medications for your needs and to avoid any potential side effects.",
        "**Yes, Ayurveda can have side effects.** However, most side effects are mild and temporary, and they can be avoided by taking Ayurvedic medicines under the guidance of a qualified Ayurvedic practitioner.\n\n**Some of the most common side effects of Ayurveda include:**\n\n* **Gastrointestinal upset:** Ayurvedic medicines can cause nausea, vomiting, diarrhea, and abdominal pain.\n* **Skin reactions:** Ayurvedic medicines can cause skin rashes, itching, and irritation.\n* **Allergic reactions:** Some people may be allergic to certain Ayurvedic medicines.\n* **Interactions with other medications:** Ayurvedic medicines can interact with other medications, including prescription drugs, over-the-counter medications, and herbal supplements.\n* **Heavy metal toxicity:** Some Ayurvedic medicines contain heavy metals, such as lead and mercury. These metals can be toxic if they are taken in high doses or for long periods of time.\n\n**It is important to talk to your doctor before taking any Ayurvedic medicines, especially if you are pregnant, breastfeeding, or have any health conditions.** Your doctor can help you to choose the right Ayurvedic medicines for your needs and to avoid any potential side effects.\n\n**Here are some tips to help reduce the risk of side effects from Ayurveda:**\n\n* **Take Ayurvedic medicines under the guidance of a qualified Ayurvedic practitioner.**\n* **Start with a low dose and gradually increase the dose as needed.**\n* **Be aware of the potential side effects of Ayurvedic medicines and watch for any adverse reactions.**\n* **Stop taking Ayurvedic medicines if you experience any side effects.**\n* **Do not take Ayurvedic medicines for long periods of time without consulting with a qualified Ayurvedic practitioner.**\n\n**Overall, Ayurveda is a safe and effective system of medicine. However, it is important to be aware of the potential side effects of Ayurvedic medicines and to take precautions to avoid them.**"
      ],
      "context": [""]
    },
    {
      "tag": "history",
      "patterns": [
        "history of ayurveda",
        "history",
        "origin of ayurveda"
      ],
      "responses": [
        "**Side Effects of Ayurvedic Medications**\n\n**Most Ayurvedic medications are considered safe when taken as directed. However, some Ayurvedic medications can cause side effects, especially if they are taken in high doses or for long periods of time.**\n\n**Some of the most common side effects of Ayurvedic medications include:**\n\n* **Gastrointestinal upset:** Ayurvedic medications can cause nausea, vomiting, diarrhea, and abdominal pain.\n* **Skin reactions:** Ayurvedic medications can cause skin rashes, itching, and irritation.\n* **Allergic reactions:** Some people may be allergic to certain Ayurvedic medications.\n* **Interactions with other medications:** Ayurvedic medications can interact with other medications, including prescription drugs, over-the-counter medications, and herbal supplements.\n* **Heavy metal toxicity:** Some Ayurvedic medications contain heavy metals, such as lead and mercury. These metals can be toxic if they are taken in high doses or for long periods of time.\n\n**It is important to talk to your doctor before taking any Ayurvedic medications, especially if you are pregnant, breastfeeding, or have any health conditions.** Your doctor can help you to choose the right Ayurvedic medications for your needs and to avoid any potential side effects.",
        "**Brief History of Ayurveda**\n\nAyurveda is a traditional system of medicine that originated in India thousands of years ago. The word Ayurveda is derived from the Sanskrit words \"ayur\" (life) and \"veda\" (knowledge). Ayurveda is thus the \"knowledge of life.\"\n\nThe origins of Ayurveda can be traced back to the ancient Vedas, which are the sacred texts of Hinduism. The Vedas contain many references to medicinal plants and healing practices. Ayurveda is also believed to have been influenced by other ancient medical systems, such as those of Egypt and Greece.\n\nOver the centuries, Ayurveda developed into a sophisticated system of medicine that encompasses a wide range of treatments, including herbal remedies, massage, yoga, and dietary changes. Ayurveda is based on the belief that health and well-being are achieved through a balance of the three doshas: vata, pitta, and kapha.\n\nAyurveda was brought to the West in the 19th century by European colonizers. However, it was not until the 1970s that Ayurveda began to gain popularity in the West. Today, Ayurveda is practiced by millions of people around the world.\n\n**Key Principles of Ayurveda**\n\n* **The three doshas:** Vata, pitta, and kapha are the three doshas, or energies, that govern the body and mind. Each dosha is associated with certain physical and mental characteristics.\n* **Balance:** Health and well-being are achieved through a balance of the three doshas.\n* **Treatment:** Ayurveda uses a variety of treatments to restore balance to the doshas, including herbal remedies, massage, yoga, and dietary changes.\n\n**Benefits of Ayurveda**\n\nAyurveda offers a number of benefits, including:\n\n* **Improved health and well-being**\n* **Reduced stress and anxiety**\n* **Boosted immunity**\n* **Improved digestion**\n* **Reduced pain and inflammation**\n\nAyurveda is a safe and effective system of medicine that can help to improve your health and well-being."
      ],
      "context": [""]
    },
    {
      "tag": "why ayurveda",
      "patterns": [
        "why ayurveda",
        "uses of ayurveda",
        "advantages of ayurveda"
      ],
      "responses": [
        "**Why Ayurveda?**\n\nAyurveda is a traditional system of medicine that has been practiced in India for thousands of years. It is based on the belief that health and well-being are achieved through a balance of the three doshas: vata, pitta, and kapha. Ayurveda uses a variety of treatments to restore balance to the doshas, including herbal remedies, massage, yoga, and dietary changes.\n\nThere are many reasons why people choose to use Ayurveda, including:\n\n* **It is a holistic system of medicine.** Ayurveda treats the whole person, not just the symptoms of an illness. This means that Ayurveda can help to improve your overall health and well-being, even if you are not suffering from a specific illness.\n* **It is a natural system of medicine.** Ayurveda uses herbs, minerals, and other natural substances to treat illnesses. This means that Ayurveda is a safe and gentle form of medicine.\n* **It is a personalized system of medicine.** Ayurveda takes into account your individual constitution when recommending treatments. This means that Ayurveda can be tailored to your specific needs.\n\n**Ayurveda can be used to treat a wide range of conditions, including:**\n\n* **Digestive disorders**\n* **Respiratory disorders**\n* **Skin disorders**\n* **Musculoskeletal disorders**\n* **Neurological disorders**\n* **Mental health disorders**\n\nAyurveda is a safe and effective system of medicine that can help to improve your health and well-being. If you are looking for a natural and holistic approach to healthcare, Ayurveda may be a good option for you.\n\nHere are some specific examples of how Ayurveda can help you:\n\n* **Improve your digestion:** Ayurveda can help to improve your digestion by balancing the doshas in your digestive tract. This can help to relieve symptoms such as gas, bloating, and constipation.\n* **Boost your immunity:** Ayurveda can help to boost your immunity by strengthening your body's natural defenses. This can help to protect you from getting sick.\n* **Reduce stress and anxiety:** Ayurveda can help to reduce stress and anxiety by balancing the doshas in your mind and body. This can help you to feel more relaxed and at peace.\n* **Improve your sleep:** Ayurveda can help to improve your sleep by balancing the doshas in your body. This can help you to fall asleep more easily and get a better night's sleep.\n* **Increase your energy levels:** Ayurveda can help to increase your energy levels by balancing the doshas in your body. This can help you to feel more energized and motivated.\n\nAyurveda is a safe and effective way to improve your health and well-being. If you are looking for a natural and holistic approach to healthcare, Ayurveda may be a good option for you.",
        "**Advantages of Ayurveda**\n\nAyurveda offers a number of advantages over other systems of medicine, including:\n\n* **Holistic approach:** Ayurveda treats the whole person, not just the symptoms of an illness. This means that Ayurveda can help to improve your overall health and well-being, even if you are not suffering from a specific illness.\n* **Natural approach:** Ayurveda uses herbs, minerals, and other natural substances to treat illnesses. This means that Ayurveda is a safe and gentle form of medicine.\n* **Personalized approach:** Ayurveda takes into account your individual constitution when recommending treatments. This means that Ayurveda can be tailored to your specific needs.\n* **Preventive approach:** Ayurveda places a strong emphasis on prevention. This means that Ayurveda can help you to stay healthy and avoid getting sick in the first place.\n* **Cost-effective:** Ayurveda is a relatively cost-effective system of medicine. This means that Ayurveda is accessible to people of all socioeconomic backgrounds.\n\n**Specific advantages of Ayurveda include:**\n\n* **Improved digestion:** Ayurveda can help to improve your digestion by balancing the doshas in your digestive tract. This can help to relieve symptoms such as gas, bloating, and constipation.\n* **Boosted immunity:** Ayurveda can help to boost your immunity by strengthening your body's natural defenses. This can help to protect you from getting sick.\n* **Reduced stress and anxiety:** Ayurveda can help to reduce stress and anxiety by balancing the doshas in your mind and body. This can help you to feel more relaxed and at peace.\n* **Improved sleep:** Ayurveda can help to improve your sleep by balancing the doshas in your body. This can help you to fall asleep more easily and get a better night's sleep.\n* **Increased energy levels:** Ayurveda can help to increase your energy levels by balancing the doshas in your body. This can help you to feel more energized and motivated.\n\nAyurveda is a safe and effective way to improve your health and well-being. If you are looking for a natural and holistic approach to healthcare, Ayurveda may be a good option for you."
      ],
      "context": [""]
    },
    {
      "tag": "ayurveda and homeopathy",
      "patterns": [
        "difference between ayurveda and homeopathy",
        "ayurveda or homeopathy",
        "which is better ayurveda or homeopathy"
      ],
      "responses": [
        "**Ayurveda** and **homeopathy** are two traditional systems of medicine that have been practiced for centuries. However, there are some key differences between the two systems.\n\n**Ayurveda**\n\n* Originated in India thousands of years ago.\n* Based on the belief that health and well-being are achieved through a balance of the three doshas: vata, pitta, and kapha.\n* Uses a variety of treatments to restore balance to the doshas, including herbal remedies, massage, yoga, and dietary changes.\n* Treats the whole person, not just the symptoms of an illness.\n* Is a natural system of medicine that uses herbs, minerals, and other natural substances to treat illnesses.\n* Is a personalized system of medicine that takes into account your individual constitution when recommending treatments.\n\n**Homeopathy**\n\n* Originated in Germany in the late 18th century.\n* Based on the belief that \"like cures like.\" This means that a substance that causes a certain set of symptoms in a healthy person can be used to cure those same symptoms in a sick person.\n* Uses highly diluted solutions of natural substances to treat illnesses.\n* Treats the symptoms of an illness, not the underlying cause.\n* Is a controversial system of medicine because there is no scientific evidence to support its claims.\n\n**Key Differences**\n\n* **Origin:** Ayurveda originated in India, while homeopathy originated in Germany.\n* **Philosophy:** Ayurveda is based on the belief that health and well-being are achieved through a balance of the three doshas, while homeopathy is based on the belief that \"like cures like.\"\n* **Treatment:** Ayurveda uses a variety of treatments to restore balance to the doshas, including herbal remedies, massage, yoga, and dietary changes, while homeopathy uses highly diluted solutions of natural substances to treat illnesses.\n* **Holistic vs. Symptom-based:** Ayurveda treats the whole person, not just the symptoms of an illness, while homeopathy treats the symptoms of an illness, not the underlying cause.\n* **Natural vs. Controversial:** Ayurveda is a natural system of medicine that uses herbs, minerals, and other natural substances to treat illnesses, while homeopathy is a controversial system of medicine because there is no scientific evidence to support its claims.\n\n**Which is better?**\n\nThere is no definitive answer to the question of which system of medicine is better, Ayurveda or homeopathy. Both systems have their own strengths and weaknesses. Ayurveda is a more holistic system of medicine that takes into account the whole person, while homeopathy is a more symptom-based system of medicine. Ultimately, the best system of medicine for you will depend on your individual needs and preferences."
      ],
      "context": [""]
    },
    {
      "tag": "ayurbot",
      "patterns": [
        "Who are you",
        "Tell about yourself"
      ],
      "responses": [
        "**Hi, I am AYURBOT, a specialized bot for the Ayurvedic specific field and its medications.**\n\nI am designed to provide information and answer questions about Ayurveda, its principles, treatments, and medications. I can also help you find qualified Ayurvedic practitioners and products.\n\nHere are some of the things I can do:\n\n* Answer your questions about Ayurveda\n* Provide information about Ayurvedic treatments and medications\n* Help you find qualified Ayurvedic practitioners\n* Help you find Ayurvedic products\n* Give you personalized Ayurvedic advice\n\nI am still under development, but I am learning more about Ayurveda every day. I am committed to providing accurate and up-to-date information about Ayurveda to help people improve their health and well-being.\n\n**How can I help you today?**"
      ],
      "context": [""]
    }
  ]
}
# Out:
# {'intents': [{'tag': 'greetings',
#    'patterns': ['Hi there', 'How are you', 'Hello'],
#    'responses': ['**Hi, I am AYURBOT, a specialized bot for the Ayurvedic specific field and its medications.**\n\nI am designed to provide information and answer questions about Ayurveda, its principles, treatments, and medications. I can also help you find qualified Ayurvedic practitioners and products.\n\nHere are some of the things I can do:\n\n* Answer your questions about Ayurveda\n* Provide information about Ayurvedic treatments and medications\n* Help you find qualified Ayurvedic practitioners\n* Help you find Ayurvedic products\n* Give you personalized Ayurvedic advice\n\nI am still under development, but I am learning more about Ayurveda every day. I am committed to providing accurate and up-to-date information about Ayurveda to help people improve their health and well-being.\n\n**How can I help you today?**'],
#    'context': ['']},
#   {'tag': 'goodbye',
# ...

# %%
vectorizer = TfidfVectorizer()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import LabelEncoder
from nltk.stem import WordNetLemmatizer

classifier = LogisticRegression(random_state=0, max_iter=10000)
patterns = []
tags = []
lemmatizer = WordNetLemmatizer()

# Collect patterns and tags from intents
for intent in intents["intents"]:
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in intent["patterns"]]
    patterns.extend(pattern_words)
    tags.extend([intent["tag"]] * len(intent["patterns"]))

# Vectorize patterns
vectorizer = CountVectorizer()
x = vectorizer.fit_transform(patterns)

# Encode tags
encoder = LabelEncoder()
encoded_tags = encoder.fit_transform(tags)

# Train the Logistic Regression model
classifier.fit(x, encoded_tags)
# Out:
# LogisticRegression(max_iter=10000, random_state=0)

# %%
def chatbot_response(text, intents_data):
    input_text = vectorizer.transform([text])
    tagsdata = classifier.predict(input_text)[0]
    for i in tagsdata:
        if i['tag'] == tag:
            result = random.choice(i['responses'])
            break
    return result

# %%
def chatbot_response(msg):
    ints = predict_class(msg, model)
    res = getResponse(ints, intents)
    return res

# %%
while True:
    query = input("User-> ")
    output = chatbot_response(query)
    print("Chatbot-> {}".format(output))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 3
#       1 while True:
#       2     query = input("User-> ")
# ----> 3     output = chatbot_response(query)
#       4     print("Chatbot-> {}".format(output))
#
# TypeError: chatbot_response() missing 1 required positional argument: 'intents_data'

# %%
# Streamlit/Flask
Homework...
Comment Code...

# %%
import nltk
import random
import json
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
from nltk.stem import WordNetLemmatizer
from sklearn.preprocessing import LabelEncoder

# Download NLTK data
nltk.download("punkt")
nltk.download("wordnet")

# Load intents data
with open('data.json') as file:
    intents = json.load(file)

# Preprocess patterns and tags
patterns = []
tags = []
lemmatizer = WordNetLemmatizer()

for intent in intents["intents"]:
    for pattern in intent["patterns"]:
        pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern.split()]
        patterns.append(" ".join(pattern_words))
        tags.append(intent["tag"])

# Vectorize patterns
vectorizer = CountVectorizer()
x = vectorizer.fit_transform(patterns)

# Encode tags
encoder = LabelEncoder()
encoded_tags = encoder.fit_transform(tags)

# Train the Logistic Regression model
classifier = LogisticRegression(random_state=0, max_iter=10000)
classifier.fit(x, encoded_tags)

def chatbot_response(text, intents_data):
    input_text = vectorizer.transform([text])
    tag = classifier.predict(input_text)[0]
    for intent in intents_data["intents"]:
        if intent["tag"] == encoder.inverse_transform([tag])[0]:
            response = random.choice(intent['responses'])
            return response

while True:
    query = input("User-> ")
    output = chatbot_response(query, intents)
    print("Chatbot-> {}".format(output))
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/shreyaschandrashekar/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/shreyaschandrashekar/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Chatbot-> **Hi, I am AYURBOT, a specialized bot for the Ayurvedic specific field and its medications.**
#
# I am designed to provide information and answer questions about Ayurveda, its principles, treatments, and medications. I can also help you find qualified Ayurvedic practitioners and products.
#
# Here are some of the things I can do:
#
# * Answer your questions about Ayurveda
# * Provide information about Ayurvedic treatments and medications
# * Help you find qualified Ayurvedic practitioners
# * Help you find Ayurvedic products
# * Give you personalized Ayurvedic advice
#
# ...
